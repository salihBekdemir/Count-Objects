# %% [markdown]
# # Count Objects

# %% [markdown]
# ### We will count the Cars and Trucks in the Pictures with Computer Vision.

# %%
#pip install cvlib

# %%
#pip install opencv-python

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib
from cvlib.object_detection import draw_bbox

# %%
img=cv2.imread('cars.webp')

# %%
plt.imshow(img)

# %%
box,label,count=cvlib.detect_common_objects(img)

# %%
output=draw_bbox(img,box,label,count)

# %%
plt.figure(figsize=(10,10))
plt.imshow(output)

# %%
label.count('car')
# Out:
# 10

# %%
label.count('person')
# Out:
# 0

# %%
label.count('truck')
# Out:
# 4

# %% [markdown]
# # In this picture, our model found 10 cars and 4 trucks
